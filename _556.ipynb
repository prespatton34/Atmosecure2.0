# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
  for filename in filenames:
    print(os.path.join(dirname, filename))

# %%
import pandas as pd
df = pd.read_csv("/content/synthetic_personal_finance_dataset.csv")

# %%
df.head()
# Out:
#   user_id  age  gender education_level employment_status    job_title  \
# 0  U00001   56  Female     High School     Self-employed  Salesperson
# 1  U00002   19  Female             PhD          Employed  Salesperson
# 2  U00003   20  Female          Master          Employed      Teacher
# 3  U00004   25    Male             PhD          Employed      Manager
# 4  U00005   53  Female             PhD          Employed      Student
#
#    monthly_income_usd  monthly_expenses_usd  savings_usd has_loan  loan_type  \
# 0             3531.69               1182.59    367655.03       No        NaN
# 1             3531.73               2367.99    260869.10      Yes  Education
# 2             2799.49               1003.91    230921.21       No        NaN
# 3             5894.88               4440.12    304815.51      Yes   Business
# 4             5128.93               4137.61    461509.48       No        NaN
#
#    loan_amount_usd  loan_term_months  monthly_emi_usd  loan_interest_rate_pct  \
# ...

# %%
df.info()
df.describe()
df.isnull().sum()
categorical_cols = df.select_dtypes(include='object').columns
for col in categorical_cols:
  print(f"\n{col}:\n", df[col].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32424 entries, 0 to 32423
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  32424 non-null  object
#  1   age                      32424 non-null  int64
#  2   gender                   32424 non-null  object
#  3   education_level          32424 non-null  object
#  4   employment_status        32424 non-null  object
#  5   job_title                32424 non-null  object
#  6   monthly_income_usd       32424 non-null  float64
#  7   monthly_expenses_usd     32424 non-null  float64
#  8   savings_usd              32424 non-null  float64
#  9   has_loan                 32424 non-null  object
#  10  loan_type                12995 non-null  object
#  11  loan_amount_usd          32424 non-null  float64
#  12  loan_term_months         32424 non-null  int64
#  13  monthly_emi_usd          32424 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='gender', palette='Set2')
plt.title("Gender Distribution")
plt.show()
# Out:
# /tmp/ipython-input-1039834454.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='gender', palette='Set2')

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='education_level', order=df['education_level'].value_counts().index, palette='cool')
plt.title("Education Level Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
# /tmp/ipython-input-2509563653.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='education_level', order=df['education_level'].value_counts().index, palette='cool')

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x='employment_status', palette='Set3')
plt.title("Employment Status")
plt.show()
# Out:
# /tmp/ipython-input-3769447240.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='employment_status', palette='Set3')

# %%
plt.figure(figsize=(8,4))
sns.countplot(data=df, x='region', palette='pastel')
plt.title("Region Distribution")
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipython-input-1798492584.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='region', palette='pastel')

# %%
sns.histplot(df['age'], kde=True, color='orange')
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['monthly_income_use'], kde=True, color='green')
plt.title("Monthly Income Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'monthly_income_use'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2655844258.py in <cell line: 0>()
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='gender', palette='Set2')
plt.title("Gender Distribution")
plt.show()

plt.figure(figsize=(10,5))
sns.countplot(data=df, x='education_level', order=df['education_level'].value_counts().index, palette='cool')
plt.title("Education Level Distribution")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(6,4))
sns.countplot(data=df, x='employment_status', palette='Set3')
plt.title("Employment Status")
plt.show()

plt.figure(figsize=(8,4))
sns.countplot(data=df, x='region', palette='pastel')
plt.title("Region Distribution")
plt.xticks(rotation=30)
plt.show()
# Out:
# /tmp/ipython-input-702175570.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='gender', palette='Set2')
# /tmp/ipython-input-702175570.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='education_level', order=df['education_level'].value_counts().index, palette='cool')
# /tmp/ipython-input-702175570.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='employment_status', palette='Set3')
# /tmp/ipython-input-702175570.py:21: FutureWarning:
#
# ...

# %%
sns.histplot(df['age'], kde=True, color='orange')
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['monthly_income_usd'], kde=True, color='green')
plt.title("Monthly Income Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x='gender', y='monthly_income_usd')
plt.title("Income by Gender")
plt.show()

# %%
sns.scatterplot(data=df, x='monthly_income_usd', y='monthly_expenses_usd', hue='gender')
plt.title("Income vs Expenses")
plt.show()

# %%
sns.histplot(df['credit_score'], bins=30, kde=True)
plt.title("Credit Score Distribution")
plt.show()

# %%
sns.histplot(df['savings_to_income_ratio'], kde=True, color='purple')
plt.title("Savings to Income Ratio Distribution")
plt.show()

# %%
sns.histplot(df['age'], kde=True, color='orange')
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['monthly_income_usd'], kde=True, color='green')
plt.title("Monthly Income Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(data=df, x='gender', y='monthly_income_usd')
plt.title("Income by Gender")
plt.show()

# %%
sns.scatterplot(data=df, x='monthly_income_usd', y='monthly_expenses_usd', hue='gender')
plt.title("Income vs Expenses")
plt.show()

# %%
sns.countplot(data=df, x='has_loan', palette='muted')
plt.title("Loan Status")
plt.show()
# Out:
# /tmp/ipython-input-1159144093.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='has_loan', palette='muted')

# %%
sns.histplot(df[df['loan_amount_usd'] > 0]['loan_amount_usd'], bins=30, kde=True)
plt.title("Loan Amount (Onlt > 0)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[df['loan_type'] != 'None'], x='loan_type', y='monthly_emi_usd')
plt.title("Monthly EMI by Loan Type")
plt.show()

# %%
sns.histplot(df['debt_to_income_ratio'], kde=True, bins=30, color='teal')
plt.title("Debt-to-Income Ratio")
plt.show()

# %%
sns.scatterplot(data=df[df['loan_interest_rate_pct'] > 0], x='credit_score', y='loan_interest_rate_pct')
plt.title("Credit Score vs Interest Rate")
plt.show()

# %%
sns.histplot(df['loan_term_months'], bins=30, kde=True)
plt.title("Loan Term (Months)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df[df['loan_type'] != 'None'], x='region', hue='loan_type')
plt.title("Loan Type by Region")
plt.xticks(rotation=30)
plt.show()

# %%
sns.histplot(df['savings_usd'], kde=True, bins=30, color='brown')
plt.title("Savings Distribution")
plt.show()

# %%
df['job_title'].value_counts().head(10).plot(kind='barh', color='skyblue')
plt.title("Top 10 Job Titles")
plt.gca().invert_yaxis()
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=df, x='education_level', y='monthly_income_usd')
plt.title("Income by Education")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.histplot(df[df['loan_amount_usd'] > 0]['loan_amount_usd'], bins=30, kde=True)
plt.title("Loan Amount (Only > 0)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df[df['loan_type'] != 'None'], x='loan_type', y='monthly_emi_usd')
plt.title("Monthly EMI by Loan Type")
plt.show()

# %%
sns.histplot(df['debt_to_income_ratio'], kde=True, bins=30, color='teal')
plt.title("Debt-to-Income Ratio")
plt.show()

# %%
sns.scatterplot(data=df[df['loan_interest_rate_pct'] > 0], x='credit_score', y='loan_interest_rate_pct')
plt.title("Credit Score vs Interest Rate")
plt.show()

# %%
df['record_date'] = pd.to_datetime(df['record_date'])
df['record_year'] = df['record_date'].dt.year
df['record_year'].value_counts().sort_index().plot(kind='bar', color='darkblue')
plt.title("Data Records Over Year")
plt.show()

# %%
sns.pairplot(df[['age', 'monthly_income_usd', 'monthly_expenses_usd', 'savings_usd']])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df[['monthly_income_usd', 'monthly_expenses_usd', 'savings_usd']])
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
sns.scatterplot(data=df, x='monthly_income_usd', y='savings_usd', hue='employment_status')
plt.title("Income vs Savings by Employment")
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='credit_score', hue='region')
plt.title("Age vs Credit Score by Region")
plt.show()
