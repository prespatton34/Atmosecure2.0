# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/content/marketing_data new.csv'):
  for filename in filenames:
    print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "User_ID": [2, 4, 8, 13, 14, 16, 20, 23, 32],
    "Engagement_Level": ["High"] * 9,
    "Likes": [
       8413654618473890, 6987951807228910, 6084337349397580, 6305220883534130,
        28112449799196700, 789156626506024, 4216867469879510, 5823293172690760,
        7228915662650600
    ],
    "Shares": [
        4824120603015070, 2914572864321600, 42713567839195900, 7537688442211050,
        9798994974874370, 41708542713567800, 20100502512562800, 2814070351758790,
        4673366834170850
    ],
    "Comments":[
        0.53, 0.27, 0.84, 7000000000000000, 0.27, 0.27, 0.18, 0.17, 0.73
    ],
    "Clicks":[
        0.74, 0.76, 0.92, 0.18, 0.34, 0.92, 0.52, 0.46, 0.08
    ],
    "Time_Spent_on_Platform":
    [4666666666666666, 0.5, 6333333333333330, 16666666666666660,
        13333333333333330, 0, 43333333333333330, 0.5, 16666666666666660]
}

df = pd.DataFrame(data)

plt.figure(figsize=(12, 6))
x_labels = df["User_ID"].astype(str)

plt.bar(x_labels, df["Likes"], label="Likes", alpha=0.8)
plt.bar(x_labels, df["Shares"], label="Shares", alpha=0.7, bottom=df["Likes"])
plt.title("Engagement Metrics per User ID", fontsize=14)
plt.xlabel("User ID", fontsize=12)
plt.ylabel("Metrics (in trillions)", fontsize=12)
plt.xticks(rotation=45)
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 8))
plt.plot(df["User_ID"], df["Likes"], label="Likes", marker="o", linestyle="--")
plt.plot(df["User_ID"], df["Shares"], label="Shares", marker="x", linestyle="-")
plt.plot(df["User_ID"], df["Comments"], label="Comments", marker="s", linestyle=":")
plt.plot(df["User_ID"], df["Clicks"], label="Clicks", marker="d", linestyle="-")

plt.title("Engagement Metrics per User ID (Crossed Lines)", fontsize=16)
plt.xlabel("User ID", fontsize=14)
plt.ylabel("Metrics", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

user_ids = [2, 4, 8, 13, 14, 16, 20, 23, 32, 34, 36, 43, 46, 47, 48, 50, 53, 56, 60, 65,
    66, 69, 79, 81, 82, 83, 84, 86, 90]

likes = [8413654618473890, 6987951807228910, 6084337349397580, 6305220883534130, 28112449799196700,
    789156626506024, 4216867469879510, 5823293172690760, 7228915662650600, 9618473895582320,
    23493975903614400, 24297188755020000, 35742971887550100, 7248995983935740, 8795180722891560,
    606425702811245, 8614457831325300, 7028112449799190, 6164658634538150, 17871485943775000,
    8433734939759030, 7429718875502000, 33132530120481900, 8132530120481920, 9638554216867460,
    8674698795180720, 46787148594377500, 5923694779116460, 7188755020080320]

shares = [4824120603015070, 2914572864321600, 42713567839195900, 7537688442211050, 9798994974874370,
    41708542713567800, 20100502512562800, 2814070351758790, 4673366834170850, 3869346733668340,
    16080402010050200, 3316582914572860, 7386934673366830, 8944723618090450, 21608040201005000,
    9045226130653260, 36683417085427100, 3618090452261300, 8140703517587930, 7035175879396980,
    19095477386934600, 17587939698492400, 7537688442211050, 3065326633165820, 6180904522613060,
    6834170854271350, 8341708542713560, 7035175879396980, 3015075376884420]

fig, ax1 = plt.subplots(figsize=(12, 6))

bar_width = 0.35
positions = np.arange(len(user_ids))
ax1.bar(positions, likes, bar_width, label='Likes', color='skyblue')

ax2 = ax1.twinx()
ax2.plot(positions, shares, label='Shares', color='orange', marker='o', linestyle='--')

ax1.set_xlabel('User IDs')
ax1.set_ylabel('Likes (Bar)', color='skyblue')
ax2.set_ylabel('Shares (Line)', color='orange')
plt.title('Engagement Metrics: Likes and Shares')

ax1.set_xticks(positions)
ax1.set_xticklabels(user_ids, rotation=45, ha='right')

ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
